# %%
# !pip install scanpy
# Out:
# Collecting scanpy
#   Downloading scanpy-1.9.6-py3-none-any.whl.metadata (6.0 kB)
# Collecting anndata>=0.7.4 (from scanpy)
#   Downloading anndata-0.9.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting get-annotations (from scanpy)
#   Downloading get_annotations-0.1.2-py3-none-any.whl (4.5 kB)
# Collecting h5py>=3 (from scanpy)
#   Downloading h5py-3.10.0-cp38-cp38-macosx_11_0_arm64.whl.metadata (2.5 kB)
# Requirement already satisfied: joblib in ./env/lib/python3.8/site-packages (from scanpy) (1.2.0)
# Requirement already satisfied: matplotlib>=3.4 in ./env/lib/python3.8/site-packages (from scanpy) (3.7.2)
# Collecting natsort (from scanpy)
#   Downloading natsort-8.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting networkx>=2.3 (from scanpy)
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 50.7 kB/s eta 0:00:0000:0100:02m
# Collecting numba>=0.41.0 (from scanpy)
#   Downloading numba-0.58.1-cp38-cp38-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Requirement already satisfied: numpy>=1.17.0 in ./env/lib/python3.8/site-packages (from scanpy) (1.24.3)
# Requirement already satisfied: packaging in ./env/lib/python3.8/site-packages (from scanpy) (23.1)
# Requirement already satisfied: pandas!=2.1.2,>=1.1.1 in ./env/lib/python3.8/site-packages (from scanpy) (2.0.3)
# Collecting patsy (from scanpy)
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 kB 102.7 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: scikit-learn>=0.24 in ./env/lib/python3.8/site-packages (from scanpy) (1.3.0)
# Requirement already satisfied: scipy>=1.4 in ./env/lib/python3.8/site-packages (from scanpy) (1.10.1)
# Collecting seaborn!=0.13.0 (from scanpy)
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 103.5 kB/s eta 0:00:0000:0100:01
# Collecting session-info (from scanpy)
#   Downloading session_info-1.0.0.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Collecting statsmodels>=0.10.0rc2 (from scanpy)
#   Downloading statsmodels-0.14.0-cp38-cp38-macosx_11_0_arm64.whl (9.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 95.6 kB/s eta 0:00:0000:01m00:03
# Collecting tqdm (from scanpy)
#   Downloading tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 22.0 kB/s eta 0:00:00a 0:00:01
# Collecting umap-learn>=0.3.10 (from scanpy)
#   Downloading umap-learn-0.5.4.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.8/90.8 kB 220.5 kB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: contourpy>=1.0.1 in ./env/lib/python3.8/site-packages (from matplotlib>=3.4->scanpy) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in ./env/lib/python3.8/site-packages (from matplotlib>=3.4->scanpy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./env/lib/python3.8/site-packages (from matplotlib>=3.4->scanpy) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./env/lib/python3.8/site-packages (from matplotlib>=3.4->scanpy) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in ./env/lib/python3.8/site-packages (from matplotlib>=3.4->scanpy) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in ./env/lib/python3.8/site-packages (from matplotlib>=3.4->scanpy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in ./env/lib/python3.8/site-packages (from matplotlib>=3.4->scanpy) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./env/lib/python3.8/site-packages (from matplotlib>=3.4->scanpy) (6.1.0)
# Collecting llvmlite<0.42,>=0.41.0dev0 (from numba>=0.41.0->scanpy)
#   Downloading llvmlite-0.41.1-cp38-cp38-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Requirement already satisfied: importlib-metadata in ./env/lib/python3.8/site-packages (from numba>=0.41.0->scanpy) (6.0.0)
# Requirement already satisfied: pytz>=2020.1 in ./env/lib/python3.8/site-packages (from pandas!=2.1.2,>=1.1.1->scanpy) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./env/lib/python3.8/site-packages (from pandas!=2.1.2,>=1.1.1->scanpy) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./env/lib/python3.8/site-packages (from scikit-learn>=0.24->scanpy) (2.2.0)
# Requirement already satisfied: six in ./env/lib/python3.8/site-packages (from patsy->scanpy) (1.16.0)
# Collecting pynndescent>=0.5 (from umap-learn>=0.3.10->scanpy)
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 112.5 kB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting stdlib_list (from session-info->scanpy)
#   Downloading stdlib_list-0.9.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: zipp>=3.1.0 in ./env/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.4->scanpy) (3.11.0)
# Downloading scanpy-1.9.6-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 68.5 kB/s eta 0:00:0000:0100:01
# Downloading anndata-0.9.2-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.2/104.2 kB 64.8 kB/s eta 0:00:00 0:00:01m
# Downloading h5py-3.10.0-cp38-cp38-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 57.8 kB/s eta 0:00:0000:0100:02m
# Downloading numba-0.58.1-cp38-cp38-macosx_11_0_arm64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 83.0 kB/s eta 0:00:0000:0100:01
# Downloading natsort-8.4.0-py3-none-any.whl (38 kB)
# Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 107.3 kB/s eta 0:00:00 0:00:01m
# Downloading llvmlite-0.41.1-cp38-cp38-macosx_11_0_arm64.whl (28.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 47.8 kB/s eta 0:00:0000:0100:20
# Downloading stdlib_list-0.9.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 160.4 kB/s eta 0:00:00a 0:00:01
# Building wheels for collected packages: umap-learn, session-info, pynndescent
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.4-py3-none-any.whl size=86758 sha256=5d37bdf2e745311b46dabcbb6587e2e9f5302fdc89cd2fbefc5e43f4fc16268f
#   Stored in directory: /Users/shubhangimore/Library/Caches/pip/wheels/b0/b0/fa/673b574ab0d1ca1b9d6000d87258c23bb6c0c5e2aae5ba73f5
#   Building wheel for session-info (setup.py) ... done
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8026 sha256=e618d070d2ab6442c2655210e058128bc371d1a3fd4eca825c6866df41ae2709
#   Stored in directory: /Users/shubhangimore/Library/Caches/pip/wheels/5c/1b/4d/111d73980c5c6a8e5e5905a19eccc34296cb359cac54c6c5b9
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55615 sha256=5325b30017652b30488f6955ce6a53def1df72d15b607df4292e8ce59fd4d623
#   Stored in directory: /Users/shubhangimore/Library/Caches/pip/wheels/f8/32/54/fa1fd0454e0441eaa32550ea2a86da3f64eb7c8e5a82436770
# Successfully built umap-learn session-info pynndescent
# Installing collected packages: tqdm, stdlib_list, patsy, networkx, natsort, llvmlite, h5py, get-annotations, session-info, numba, statsmodels, seaborn, pynndescent, anndata, umap-learn, scanpy
# Successfully installed anndata-0.9.2 get-annotations-0.1.2 h5py-3.10.0 llvmlite-0.41.1 natsort-8.4.0 networkx-3.1 numba-0.58.1 patsy-0.5.3 pynndescent-0.5.10 scanpy-1.9.6 seaborn-0.12.2 session-info-1.0.0 statsmodels-0.14.0 stdlib_list-0.9.0 tqdm-4.66.1 umap-learn-0.5.4

# %%
import scanpy as sc
import pandas as pd
import numpy as np

# %%
# !conda install -y -c anaconda cmake 
# !pip install leidenalg
# !pip install louvain
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 23.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.9.0
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/shubhangimore/scanpy/env
#
#   added / updated specs:
#     - cmake
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bzip2-1.0.8                |       h620ffc9_4         147 KB  anaconda
#     c-ares-1.19.1              |       h80987f9_0         104 KB  anaconda
#     ca-certificates-2023.08.22 |       hca03da5_0         131 KB  anaconda
#     certifi-2023.7.22          |   py38hca03da5_0         156 KB  anaconda
#     cmake-3.26.4               |       h5d7ac33_0        14.6 MB  anaconda
#     expat-2.5.0                |       h313beb8_0         155 KB  anaconda
#     libcurl-7.88.1             |       h3e2b118_2         325 KB  anaconda
#     libev-4.33                 |       h1a28f6b_1         100 KB  anaconda
#     libnghttp2-1.57.0          |       h62f6fdd_0         712 KB  anaconda
#     libssh2-1.10.0             |       h02f6b3c_2         327 KB  anaconda
#     libuv-1.44.2               |       h80987f9_0         464 KB  anaconda
#     openssl-3.0.11             |       h1a28f6b_2         4.5 MB  anaconda
#     rhash-1.4.3                |       h02f6b3c_0         253 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:        21.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   bzip2              anaconda/osx-arm64::bzip2-1.0.8-h620ffc9_4
#   c-ares             anaconda/osx-arm64::c-ares-1.19.1-h80987f9_0
#   cmake              anaconda/osx-arm64::cmake-3.26.4-h5d7ac33_0
#   expat              anaconda/osx-arm64::expat-2.5.0-h313beb8_0
#   libcurl            anaconda/osx-arm64::libcurl-7.88.1-h3e2b118_2
#   libev              anaconda/osx-arm64::libev-4.33-h1a28f6b_1
#   libnghttp2         anaconda/osx-arm64::libnghttp2-1.57.0-h62f6fdd_0
#   libssh2            anaconda/osx-arm64::libssh2-1.10.0-h02f6b3c_2
#   libuv              anaconda/osx-arm64::libuv-1.44.2-h80987f9_0
#   rhash              anaconda/osx-arm64::rhash-1.4.3-h02f6b3c_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates                                 pkgs/main --> anaconda
#   certifi                                         pkgs/main --> anaconda
#   openssl                                         pkgs/main --> anaconda
#
#
#
# Downloading and Extracting Packages
# openssl-3.0.11       | 4.5 MB    |                                       |   0%
# libnghttp2-1.57.0    | 712 KB    |                                       |   0%
#
# expat-2.5.0          | 155 KB    |                                       |   0%
#
#
# libev-4.33           | 100 KB    |                                       |   0%
#
#
#
# ca-certificates-2023 | 131 KB    |                                       |   0%
#
#
#
#
# libssh2-1.10.0       | 327 KB    |                                       |   0%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   |                                       |   0%
#
#
#
#
#
#
# rhash-1.4.3          | 253 KB    |                                       |   0%
#
#
#
#
#
#
#
# bzip2-1.0.8          | 147 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# certifi-2023.7.22    | 156 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# libuv-1.44.2         | 464 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# c-ares-1.19.1        | 104 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.0.11       | 4.5 MB    | 1                                     |   0%
#
#
# libev-4.33           | 100 KB    | #####9                                |  16%
#
#
#
# openssl-3.0.11       | 4.5 MB    | #9                                    |   5%
#
#
# libev-4.33           | 100 KB    | ##################################### | 100%
#
#
# openssl-3.0.11       | 4.5 MB    | #######2                              |  20%
#
#
#
#
# libssh2-1.10.0       | 327 KB    | #8                                    |   5%
#
#
#
# ca-certificates-2023 | 131 KB    | ##################################### | 100%
#
# expat-2.5.0          | 155 KB    | ###8                                  |  10%
#
#
#
# ca-certificates-2023 | 131 KB    | ##################################### | 100%
# libnghttp2-1.57.0    | 712 KB    | 8                                     |   2%
#
#
#
#
#
# openssl-3.0.11       | 4.5 MB    | ##########                            |  27%
#
#
#
#
# libssh2-1.10.0       | 327 KB    | #######################5              |  64%
# libnghttp2-1.57.0    | 712 KB    | ########3                             |  22%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | 1                                     |   0%
#
# expat-2.5.0          | 155 KB    | ###########4                          |  31%
#
#
#
#
# libssh2-1.10.0       | 327 KB    | ####################################2 |  98%
# openssl-3.0.11       | 4.5 MB    | ############2                         |  33%
#
# expat-2.5.0          | 155 KB    | ##################################### | 100%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | 7                                     |   2%
#
#
#
#
# libssh2-1.10.0       | 327 KB    | ##################################### | 100%
# libnghttp2-1.57.0    | 712 KB    | ##################################    |  92%
#
#
#
#
#
#
#
# openssl-3.0.11       | 4.5 MB    | #################4                    |  47%
# libnghttp2-1.57.0    | 712 KB    | ##################################### | 100%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | #1                                    |   3%
#
#
#
#
#
#
# rhash-1.4.3          | 253 KB    | ##3                                   |   6%
#
#
#
#
#
#
#
# bzip2-1.0.8          | 147 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# openssl-3.0.11       | 4.5 MB    | ###################9                  |  54%
#
#
#
#
#
#
# rhash-1.4.3          | 253 KB    | #######################3              |  63%
#
#
#
#
#
# openssl-3.0.11       | 4.5 MB    | #######################5              |  64%
#
#
#
#
#
#
# rhash-1.4.3          | 253 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# c-ares-1.19.1        | 104 KB    | #####6                                |  15%
#
#
#
#
#
# openssl-3.0.11       | 4.5 MB    | ##########################1           |  71%
#
#
#
#
#
#
#
#
#
# openssl-3.0.11       | 4.5 MB    | ############################9         |  78%
#
#
#
#
#
#
#
#
#
# libuv-1.44.2         | 464 KB    | ###########4                          |  31%
#
#
#
#
#
#
#
#
#
#
# c-ares-1.19.1        | 104 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# c-ares-1.19.1        | 104 KB    | ##################################### | 100%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ##6                                   |   7%
#
#
#
#
#
#
#
#
# certifi-2023.7.22    | 156 KB    | ###7                                  |  10%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ###                                   |   8%
#
#
#
#
#
#
#
#
#
# libuv-1.44.2         | 464 KB    | #########################4            |  69%
#
#
#
#
#
#
#
#
# certifi-2023.7.22    | 156 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# certifi-2023.7.22    | 156 KB    | ##################################### | 100%
# openssl-3.0.11       | 4.5 MB    | ###############################5      |  85%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ###3                                  |   9%
#
#
#
#
#
#
#
#
#
# libuv-1.44.2         | 464 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# openssl-3.0.11       | 4.5 MB    | ##################################7   |  94%
#
#
#
#
#
#
#
#
#
#
#
# libcurl-7.88.1       | 325 KB    | #############################1        |  79%
#
#
#
#
#
#
#
#
#
#
#
# libcurl-7.88.1       | 325 KB    | ##################################### | 100%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ###8                                  |  10%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ####2                                 |  12%
#
#
#
#
#
# openssl-3.0.11       | 4.5 MB    | ##################################### | 100%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | #####                                 |  14%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | #####4                                |  15%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | #####9                                |  16%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ######3                               |  17%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ######6                               |  18%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | #######                               |  19%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | #######4                              |  20%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | #######7                              |  21%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ########                              |  22%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ########3                             |  23%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ########5                             |  23%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ########7                             |  24%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ########9                             |  24%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | #########1                            |  25%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | #########7                            |  26%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ##########1                           |  28%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ##########4                           |  28%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ##########8                           |  29%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ###########1                          |  30%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ###########9                          |  32%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ############4                         |  34%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | #############5                        |  37%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | #############9                        |  38%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ##############5                       |  39%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ###############                       |  41%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ###############6                      |  42%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ################                      |  43%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ################6                     |  45%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | #################1                    |  46%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | #################6                    |  48%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ##################1                   |  49%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ##################6                   |  50%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ###################3                  |  52%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ###################9                  |  54%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ####################6                 |  56%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | #####################2                |  58%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | #####################9                |  59%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ######################6               |  61%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | #######################4              |  63%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ########################              |  65%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ########################6             |  67%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | #########################2            |  68%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | #########################7            |  70%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ##########################2           |  71%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ##########################7           |  72%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ###########################2          |  74%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ###########################9          |  76%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ############################4         |  77%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | #############################         |  79%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | #############################7        |  80%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ##############################4       |  82%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ###############################       |  84%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ###############################6      |  86%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ################################2     |  87%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ################################8     |  89%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | #################################4    |  90%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ##################################    |  92%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ##################################5   |  94%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ####################################1 |  98%
#
#
#
#
#
# cmake-3.26.4         | 14.6 MB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting leidenalg
#   Downloading leidenalg-0.10.1-cp38-abi3-macosx_11_0_arm64.whl.metadata (10 kB)
# Collecting igraph<0.11,>=0.10.0 (from leidenalg)
#   Downloading igraph-0.10.8-cp38-cp38-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Collecting texttable>=1.6.2 (from igraph<0.11,>=0.10.0->leidenalg)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Downloading leidenalg-0.10.1-cp38-abi3-macosx_11_0_arm64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 90.4 kB/s eta 0:00:0000:0100:01m
# Downloading igraph-0.10.8-cp38-cp38-macosx_11_0_arm64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 82.5 kB/s eta 0:00:0000:0100:01
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, igraph, leidenalg
# Successfully installed igraph-0.10.8 leidenalg-0.10.1 texttable-1.7.0
# Collecting louvain
#   Downloading louvain-0.8.1-cp38-cp38-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Requirement already satisfied: igraph<0.11,>=0.10.0 in ./env/lib/python3.8/site-packages (from louvain) (0.10.8)
# Requirement already satisfied: texttable>=1.6.2 in ./env/lib/python3.8/site-packages (from igraph<0.11,>=0.10.0->louvain) (1.7.0)
# Downloading louvain-0.8.1-cp38-cp38-macosx_11_0_arm64.whl (189 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.7/189.7 kB 209.2 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: louvain
# Successfully installed louvain-0.8.1

# %%
adata = sc.read_h5ad("GTEx_8_tissues_snRNAseq_immune_atlas_071421.public_obs.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 14156 × 16150
#     obs: 'n_genes', 'tissue', 'prep', 'individual', 'nGenes', 'nUMIs', 'PercentMito', 'PercentRibo', 'Age_bin', 'Sex', 'Sample ID', 'participant_id', 'Sample ID short', 'Sample Ischemic Time (mins)', 'Tissue Site Detail', 'scrublet', 'scrublet_score', 'barcode', 'batch', 'annotation', 'broad', 'granular', 'leiden', 'Tissue', 'LAM_prediction'
#     var: 'gene_ids', 'Chromosome', 'gene_name', 'gene_biotype', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'Sex_colors', 'Tissue_colors', 'annotation_colors', 'annotation_sizes', 'broad_colors', 'dendrogram_annotation', 'dendrogram_leiden', 'granular_colors', 'hvg', 'lam_02_colors', 'leiden', 'leiden_DE', 'neighbors', 'paga', 'participant_id_colors', 'pca', 'prediction_colors', 'prep_colors', 'rank_genes_groups', 'tissue_colors', 'umap'
#     obsm: 'X_harmony', 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
adata.var['mt'] = adata.var_names.str.startswith('MT-')

# %%
adata.var['mt']
# Out:
# FO538757.2    False
# SAMD11        False
# NOC2L         False
# KLHL17        False
# PLEKHN1       False
#               ...
# C21orf58      False
# PCNT          False
# DIP2A         False
# S100B         False
# PRMT2         False
# Name: mt, Length: 16150, dtype: bool

# %%
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

# %%
sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'], jitter=0.4, multi_panel=True)
# Out:
# /Users/shubhangimore/scanpy/env/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
adata.var['mt']
